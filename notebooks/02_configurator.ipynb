# %% [markdown]
# # UAV Battery Tool — Analysis Configurator
#
# Run this notebook first. Select your UAV, mission, temperature, and batteries, then save.
# All other notebooks will load these settings automatically from `analysis_config.json`.

# %%
import sys, os, json
sys.path.insert(0, os.path.abspath('..'))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings; warnings.filterwarnings('ignore')

from batteries.database import BatteryDatabase

plt.rcParams.update({'figure.dpi': 110, 'font.size': 10, 'axes.grid': True, 'grid.alpha': 0.25})
DB_PATH   = '../battery_db.xlsx'
# Save config to project root (one level up from notebooks/)
CFG_PATH  = ('../analysis_config.json'
             if not __import__('os').path.exists('analysis_config.json')
             or __import__('os').path.exists('../analysis_config.json')
             else 'analysis_config.json')
db = BatteryDatabase(DB_PATH).load()
print(db.summary())
# Out:
# ═══ Battery Database Summary ═══
#   Chemistries       : 9
#   Cells             : 11
#   Battery packs     : 125
#   Discharge points  : 132
#   Equipment items   : 29
#   UAV configurations: 3
#   Mission profiles  : 3

# %% [markdown]
# ## 1 · UAV Selection

# %%
print('Available UAV configurations:\n')
uav_rows = []
for uid, uav in db.uav_configs.items():
    total_w  = sum(e.weight_g * q for e, q in uav.equipment_list)
    hover_w  = sum(e.hover_power_w * q for e, q in uav.equipment_list)
    cruise_w = sum(e.cruise_power_w * q for e, q in uav.equipment_list)
    uav_rows.append({
        'UAV_ID':        uid,
        'Equipment items': len(uav.equipment_list),
        'Total weight (g)': round(total_w, 0),
        'Hover power (W)':  round(hover_w, 0),
        'Cruise power (W)': round(cruise_w, 0),
    })
df_uav = pd.DataFrame(uav_rows)
print(df_uav.to_string(index=False))

print('\nEquipment detail per UAV:')
for uid, uav in db.uav_configs.items():
    print(f'  {uid}:')
    for equip, qty in uav.equipment_list:
        print(f'    x{qty}  {equip.equip_id:<30}  {equip.category}')
# Out:
# Available UAV configurations:
#
#         UAV_ID  Equipment items  Total weight (g)  Hover power (W)  Cruise power (W)
# HEX_SURVEY_900               11            3073.0            368.0             308.0
#    HEX_AG_1200               10            4690.0            636.0             516.0
#   QUAD_INSPECT               10            1492.0            169.0             141.0
#
# Equipment detail per UAV:
#   HEX_SURVEY_900:
#     x6  MOT_T_MOTOR_MN4014              Propulsion
#     x6  ESC_FLAME_60A                   Propulsion
#     x1  FC_PIXHAWK_6C                   Avionics
#     x1  GPS_HERE3                       Avionics
#     x1  CAM_RGB_10MP                    Payload
#     x1  GIMBAL_3AXIS                    Payload
#     x1  RC_CROSSFIRE                    Communication
#     x1  TELEMETRY_900MHZ                Communication
#     x1  POWER_MODULE_60A                Power Systems
#     x1  BMS_ACTIVE                      Power Systems
#     x1  FRAME_HEX_900                   Frame/Structure
#   HEX_AG_1200:
#     x6  MOT_HOBBYWING_X8                Propulsion
#     x6  ESC_FLAME_80A                   Propulsion
#     x1  FC_CUBE_ORANGE                  Avionics
#     x1  GPS_F9P_RTK                     Avionics
#     x1  MULTISPECTRAL_MX                Payload
#     x1  RC_CROSSFIRE                    Communication
#     x1  TELEMETRY_900MHZ                Communication
#     x1  POWER_MODULE_60A                Power Systems
#     x1  BMS_ACTIVE                      Power Systems
#     x1  FRAME_HEX_1200                  Frame/Structure
#   QUAD_INSPECT:
#     x4  MOT_SUNNYSKY_X2216              Propulsion
#     x4  ESC_FLAME_60A                   Propulsion
#     x1  FC_PIXHAWK_6C                   Avionics
#     x1  GPS_HERE3                       Avionics
#     x1  THERMAL_VUE_PRO                 Payload
#     x1  GIMBAL_3AXIS                    Payload
#     x1  RC_CROSSFIRE                    Communication
#     x1  VIDEO_TX_5G8                    Communication
#     x1  POWER_MODULE_60A                Power Systems
#     x1  FRAME_QUAD_450                  Frame/Structure

# %%
UAV_ID = 'HEX_SURVEY_900'      # <── change this

# Optional: override specific equipment quantities.
# Format: {equip_id: quantity}  — items not listed keep their preset qty.
# Example: CUSTOM_EQUIPMENT = {'MOT_T_MOTOR_MN601S': 8, 'CAM_SONY_A7R': 0}
CUSTOM_EQUIPMENT = {}

# ─────────────────────────────────────────────────────────────────────────────
if UAV_ID not in db.uav_configs:
    raise ValueError(f'UAV_ID "{UAV_ID}" not found. Choose from: {list(db.uav_configs)}')

uav = db.uav_configs[UAV_ID]
print(f'Selected: {UAV_ID}')
print(f'  Equipment:')
equip_list = []
for equip, qty in uav.equipment_list:
    eid = equip.equip_id
    q   = CUSTOM_EQUIPMENT.get(eid, qty)
    if q > 0:
        print(f'    x{q}  {eid:<35} hover={equip.hover_power_w*q:.0f}W  cruise={equip.cruise_power_w*q:.0f}W')
        equip_list.append({'equip_id': eid, 'qty': q})

hover_total  = sum(db.equipment[e['equip_id']].hover_power_w  * e['qty'] for e in equip_list)
cruise_total = sum(db.equipment[e['equip_id']].cruise_power_w * e['qty'] for e in equip_list)
print(f'  Total hover power : {hover_total:.0f} W')
print(f'  Total cruise power: {cruise_total:.0f} W')
# Out:
# Selected: HEX_SURVEY_900
#   Equipment:
#     x6  MOT_T_MOTOR_MN4014                  hover=330W  cruise=270W
#     x6  ESC_FLAME_60A                       hover=18W  cruise=18W
#     x1  FC_PIXHAWK_6C                       hover=4W  cruise=4W
#     x1  GPS_HERE3                           hover=0W  cruise=0W
#     x1  CAM_RGB_10MP                        hover=2W  cruise=2W
#     x1  GIMBAL_3AXIS                        hover=6W  cruise=6W
#     x1  RC_CROSSFIRE                        hover=1W  cruise=1W
#     x1  TELEMETRY_900MHZ                    hover=1W  cruise=1W
#     x1  POWER_MODULE_60A                    hover=2W  cruise=2W
#     x1  BMS_ACTIVE                          hover=2W  cruise=2W
#     x1  FRAME_HEX_900                       hover=0W  cruise=0W
#   Total hover power : 368 W
#   Total cruise power: 308 W

# %% [markdown]
# ## 2 · Mission Profile Selection

# %%
print('Available mission profiles:\n')
mission_rows = []
for mid, m in db.missions.items():
    total_s   = sum(ph.duration_s for ph in m.phases)
    total_km  = sum(getattr(ph, 'distance_m', 0) or 0 for ph in m.phases) / 1000
    phases    = ', '.join(ph.phase_type for ph in m.phases)
    mission_rows.append({
        'Mission_ID':    mid,
        'Duration (s)':  int(total_s),
        'Distance (km)': round(total_km, 1),
        'Phase sequence': phases,
    })
df_missions = pd.DataFrame(mission_rows)
print(df_missions.to_string(index=False))

print('\nPhase detail per mission:')
for mid, m in db.missions.items():
    print(f'  {mid}:')
    for ph in m.phases:
        pw = getattr(ph, 'power_override_w', None)
        print(f'    [{ph.phase_type:<12}] {ph.duration_s:>5}s  '
              f'dist={getattr(ph,"distance_m",0) or 0:>6.0f}m  '
              f'{("power_override="+str(pw)+"W") if pw else ""}')
# Out:
# Available mission profiles:
#
#  Mission_ID  Duration (s)  Distance (km)                                                     Phase sequence
#  SURVEY_STD          1470            6.7         IDLE, TAKEOFF, CLIMB, CRUISE, HOVER, CRUISE, DESCEND, LAND
#    AG_SPRAY          1110            2.6 IDLE, TAKEOFF, CRUISE, CRUISE, HOVER, CRUISE, CRUISE, CRUISE, LAND
# INSPECT_STD           850            0.3          IDLE, TAKEOFF, CLIMB, HOVER, CRUISE, HOVER, DESCEND, LAND
#
# Phase detail per mission:
#   SURVEY_STD:
#     [IDLE        ]  60.0s  dist=     0m
#     [TAKEOFF     ]  30.0s  dist=     0m
#     [CLIMB       ]  60.0s  dist=   200m
#     [CRUISE      ] 900.0s  dist=  4500m
#     [HOVER       ]  30.0s  dist=     0m
#     [CRUISE      ] 300.0s  dist=  2000m
#     [DESCEND     ]  60.0s  dist=     0m
#     [LAND        ]  30.0s  dist=     0m
#   AG_SPRAY:
#     [IDLE        ]  90.0s  dist=     0m
#     [TAKEOFF     ]  20.0s  dist=     0m
#     [CRUISE      ] 120.0s  dist=   600m
#     [CRUISE      ] 240.0s  dist=   480m
#     [HOVER       ]  15.0s  dist=     0m
#     [CRUISE      ] 240.0s  dist=   480m
#     [CRUISE      ] 240.0s  dist=   480m
#     [CRUISE      ] 120.0s  dist=   600m
#     [LAND        ]  25.0s  dist=     0m
#   INSPECT_STD:
#     [IDLE        ]  60.0s  dist=     0m
#     [TAKEOFF     ]  20.0s  dist=     0m
#     [CLIMB       ]  90.0s  dist=     0m
#     [HOVER       ] 300.0s  dist=     0m
#     [CRUISE      ] 240.0s  dist=   300m
#     [HOVER       ]  60.0s  dist=     0m
#     [DESCEND     ]  60.0s  dist=     0m
#     [LAND        ]  20.0s  dist=     0m

# %%
# ── SELECT YOUR MISSION ──────────────────────────────────────────────────────
MISSION_ID = 'SURVEY_STD'      # <── change this

# ─────────────────────────────────────────────────────────────────────────────
if MISSION_ID not in db.missions:
    raise ValueError(f'MISSION_ID "{MISSION_ID}" not found. Choose from: {list(db.missions)}')

mission = db.missions[MISSION_ID]
total_s = sum(ph.duration_s for ph in mission.phases)
print(f'Selected: {MISSION_ID}  ({total_s}s / {total_s/60:.1f} min)')

# Power profile bar chart
fig, ax = plt.subplots(figsize=(10, 4))
PHASE_COLORS = {
    'IDLE':            '#AAAAAA',  # ground idle
    'TAKEOFF':         '#FF9944',  # full power lift-off
    'CLIMB':           '#FFCC44',  # powered climb
    'CRUISE':          '#44AA66',  # level cruise
    'HOVER':           '#4488FF',  # stationary hover
    'DESCEND':         '#88AADD',  # descent
    'LAND':            '#CC88DD',  # landing
    'PAYLOAD_OPS':     '#FF6688',  # payload operations
    'EMERGENCY':       '#FF2222',  # emergency
    # ── Fixed-wing VTOL phases ────────────────────────────────────────────
    'VTOL_TRANSITION': '#FF6611',  # lift+thrust overlap during transition
    'VTOL_HOVER':      '#22AAFF',  # explicit multirotor hover
    'FW_CRUISE':       '#00CC77',  # efficient fixed-wing cruise
    'FW_CLIMB':        '#AACC44',  # fixed-wing climb
    'FW_DESCEND':      '#99CCEE',  # glide descent
}
x_pos = 0
for ph in mission.phases:
    color = PHASE_COLORS.get(ph.phase_type, '#CCC')
    ax.barh(0, ph.duration_s, left=x_pos, height=0.6, color=color, edgecolor='white')
    ax.text(x_pos + ph.duration_s/2, 0, ph.phase_type + chr(10) + str(int(ph.duration_s)) + 's',
            ha='center', va='center', fontsize=8, fontweight='bold', color='white')
    x_pos += ph.duration_s
ax.set_xlim(0, x_pos); ax.set_yticks([])
ax.set_xlabel('Time (s)'); ax.set_title(f'{MISSION_ID} — Phase Timeline')
plt.tight_layout(); plt.show()
# Out:
# Selected: SURVEY_STD  (1470.0s / 24.5 min)

# %% [markdown]
# ## 3 · Temperature Configuration

# %%
# ── SET TEMPERATURE ───────────────────────────────────────────────────────────
# For a single analysis temperature:
AMBIENT_TEMP_C = 25.0          # <── change this

# For a temperature sweep (used in Notebook 03 and the scorecard):
# Leave TEMP_SWEEP_RANGE as None to use AMBIENT_TEMP_C only.
# Or set to (min, max, step) to sweep a range.
TEMP_SWEEP_RANGE = (-10, 45, 5)   # (min_C, max_C, step_C) — or None

# ─────────────────────────────────────────────────────────────────────────────
if TEMP_SWEEP_RANGE:
    t_min, t_max, t_step = TEMP_SWEEP_RANGE
    TEMP_SWEEP = list(range(int(t_min), int(t_max) + 1, int(t_step)))
else:
    TEMP_SWEEP = [AMBIENT_TEMP_C]

print(f'Primary temperature   : {AMBIENT_TEMP_C}°C')
print(f'Temperature sweep     : {TEMP_SWEEP}')

# Visual summary
fig, ax = plt.subplots(figsize=(10, 2))
ax.barh(0, max(TEMP_SWEEP) - min(TEMP_SWEEP), left=min(TEMP_SWEEP),
        height=0.5, color='#2196F3', alpha=0.35, edgecolor='#2196F3')
ax.axvline(AMBIENT_TEMP_C, color='#E53935', linewidth=2, label=f'Primary: {AMBIENT_TEMP_C}°C')
for t in TEMP_SWEEP:
    ax.axvline(t, color='steelblue', linewidth=0.8, linestyle='--', alpha=0.6)
ax.set_xlabel('Temperature (°C)'); ax.set_yticks([])
ax.set_title('Temperature Configuration'); ax.legend()
plt.tight_layout(); plt.show()
# Out:
# Primary temperature   : 25.0°C
# Temperature sweep     : [-10, -5, 0, 5, 10, 15, 20, 25, 30, 35, 40, 45]

# %% [markdown]
# ## 4 · Battery Selection

# %%
print('Battery catalogue:\n')
batt_rows = []
for bid, p in db.packs.items():
    batt_rows.append({
        'Battery_ID':      bid,
        'Chemistry':       p.chemistry_id,
        'Config':          f'{p.cells_series}S{p.cells_parallel}P',
        'Voltage (V)':     round(p.pack_voltage_nom, 1),
        'Capacity (Ah)':   round(p.pack_capacity_ah, 1),
        'Energy (Wh)':     round(p.pack_energy_wh, 1),
        'Weight (g)':      round(p.pack_weight_g, 0),
        'IR (mΩ)':         round(p.internal_resistance_mohm, 1),
        'Max cont. (A)':   round(p.max_cont_discharge_a, 0),
        'UAV class':       getattr(p, 'uav_class', ''),
    })
df_batt = pd.DataFrame(batt_rows)
print(df_batt.to_string(index=False))
# Out:
# Battery catalogue:
#
#                                         Battery_ID Chemistry Config  Voltage (V)  Capacity (Ah)  Energy (Wh)  Weight (g)  IR (mΩ)  Max cont. (A)       UAV class
#                                       BAT_FPV_4S1P      LIPO   4S1P         14.8            1.3         19.2       128.0     15.0           65.0    FPV / Racing
#                                       BAT_MICRO_1S      LIHV   1S1P          3.9            0.6          2.1        14.0     30.0            5.0       Micro UAV
#                                       BAT_MID_6S2P    LION21   6S2P         21.9            9.0        197.0       840.0     28.0           90.0  Inspection UAV
#                                       BAT_MID_6S4P    LION21   6S4P         21.8           20.0        436.0      1692.0     88.0           56.0  Long Endurance
#                                        BAT_AG_6S1P   LIFEPO4   6S1P         19.2           10.0        192.0      1860.0      5.0           30.0 Agriculture UAV
#                                     BAT_HLIFT_6S2P   LIFEPO4   6S2P         19.8            5.0         99.0       912.0     16.0          140.0  Heavy Lift UAV
#                                       BAT_LE_12S2P    LION21  12S2P         43.8            8.0        350.0      1656.0     36.0           70.0 Fixed Wing VTOL
#                                       BAT_SSS_6S1P       SSS   6S1P         22.2            5.0        111.0       606.0     20.0           12.0    Next-Gen UAV
# TATTU_TATTU_ULTRA_HIGH_VOLTAGE_41000MAH_5C_23_7V_6      LIPO   6S7P         22.2           41.0        910.2      3790.0     42.0          205.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_350WH_KG_33000MAH_10C      LIPO  14S1P         51.8           33.0       1709.4      5486.0     14.0          330.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_330WH_KG_33000MAH_10C      LIPO  14S1P         51.8           33.0       1709.4      5701.0     14.0          330.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_330WH_KG_76000MAH_10C      LIPO  12S1P         44.4           76.0       3374.4     10949.0     12.0          760.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_330WH_KG_25000MAH_10C      LIPO  12S1P         44.4           25.0       1110.0      3788.0     12.0          125.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_300WH_KG_30000MAH_10C      LIPO  12S1P         44.4           30.0       1332.0      4900.0     12.0          300.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_300WH_KG_25000MAH_10C      LIPO   6S7P         22.2           25.0        555.0      2048.0     42.0          250.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_300WH_KG_22000MAH_10C      LIPO   6S7P         22.2           22.0        488.4      1807.0     42.0          220.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_300WH_KG_17000MAH_10C      LIPO   6S7P         22.2           17.0        377.4      1432.0     42.0          170.0  Industrial UAV
# TATTU_TATTU_ULTRA_HIGH_VOLTAGE_41000MAH_5C_47_4V_1      LIPO   6S1P         22.2           41.0        910.2      7250.0      6.0          205.0  Industrial UAV
# TATTU_TATTU_ULTRA_HIGH_VOLTAGE_32000MAH_5C_23_7V_6      LIPO   6S7P         22.2           32.0        710.4      3220.0     42.0          160.0  Industrial UAV
# TATTU_TATTU_ULTRA_HIGH_VOLTAGE_22000MAH_5C_23_7V_6      LIPO   6S7P         22.2           22.0        488.4      2270.0     42.0          110.0  Industrial UAV
# TATTU_TATTU_ULTRA_HIGH_VOLTAGE_17000MAH_5C_23_7V_6      LIPO   6S7P         22.2           17.0        377.4      1760.0     42.0           85.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_22000MAH_5C_22_2V_6S1P_XT90      LIPO   6S7P         22.2           22.0        488.4      2250.0     42.0          110.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_17000MAH_5C_22_2V_6S1P_G_TE      LIPO   6S7P         22.2           17.0        377.4      1600.0     42.0           85.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_30000MAH_5C_44_4V_12S      LIPO  12S1P         44.4           30.0       1332.0      4900.0     12.0          150.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_30000MAH_22_2V_5C_6S1      LIPO   6S7P         22.2           30.0        666.0      2525.0     42.0          150.0  Industrial UAV
# TATTU_TATTU_4_0_20000MAH_53_2V_14S1P_35C_LIPO_SMAR      LIPO  14S1P         51.8           20.0       1036.0      7900.0     14.0          500.0  Industrial UAV
# TATTU_TATTU_AGRI_22000MAH_44_4V_25C_12S1P_LIPO_BAT      LIPO  12S1P         44.4           22.0        976.8      5850.0     12.0          550.0  Industrial UAV
# TATTU_TATTU_AGRI_16000MAH_44_4V_15C_12S1P_LIPO_BAT      LIPO  12S1P         44.4           16.0        710.4      5850.0     12.0          240.0  Industrial UAV
# TATTU_TATTU_AGRI_22000MAH_45_6V_25C_12S1P_HIGH_VOL      LIPO  12S1P         44.4           22.0        976.8      5850.0     12.0          550.0  Industrial UAV
# TATTU_TATTU_AGRI_16000MAH_45_6V_25C_12S1P_HIGH_VOL      LIPO  12S1P         44.4           16.0        710.4      4550.0     12.0          400.0  Industrial UAV
# TATTU_TATTU_PRO_22000MAH_53_2V_25C_14S1P_HV_LIPO_S      LIPO  14S1P         51.8           22.0       1139.6      6550.0     14.0          550.0  Industrial UAV
# TATTU_TATTU_PRO_22000MAH_45_6V_25C_12S1P_HV_LIPO_S      LIPO  12S1P         44.4           22.0        976.8      5750.0     12.0          550.0  Industrial UAV
# TATTU_TATTU_3S_6000MAH_15C_11_4V_G_TECH_LIPO_BATTE      LIPO   3S4P         11.1            6.0         66.6       385.0     12.0           90.0  Industrial UAV
# TATTU_TATTU_PLUS_1_0_COMPACT_VERSION_10000MAH_44_4      LIPO  12S1P         44.4           10.0        444.0      2978.0     12.0          150.0  Industrial UAV
# TATTU_TATTU_PLUS_22000MAH_44_4V_25C_12S1P_LIPO_SMA      LIPO  12S1P         44.4           22.0        976.8      5800.0     12.0          550.0  Industrial UAV
# TATTU_TATTU_SEMI_SOLID_STATE_20000MAH_6S_5C_22_2V_      LIPO   6S7P         22.2           20.0        444.0      1000.0     42.0          100.0  Industrial UAV
# TATTU_TATTU_G_TECH_4S_22000MAH_14_8V_25C_LIPO_BATT      LIPO   4S5P         14.8           22.0        325.6      1000.0     20.0          550.0  Industrial UAV
# TATTU_TATTU_G_TECH_30000MAH_6S_22_2V_25C_LIPO_BATT      LIPO   6S7P         22.2           30.0        666.0      3500.0     42.0          750.0  Industrial UAV
# TATTU_TATTU_PLUS_16000MAH_6S_15C_22_2V_LIPO_BATTER      LIPO   6S9P         22.2           16.0        355.2      1932.0     54.0          240.0  Industrial UAV
# TATTU_TATTU_PRO_22000MAH_51_8V_25C_14S_1P_LIPO_SMA      LIPO  14S1P         51.8           22.0       1139.6      7350.0     14.0          550.0  Industrial UAV
# TATTU_TATTU_PRO_22000MAH_44_4V_25C_12S_1P_LIPO_SMA      LIPO  12S1P         44.4           22.0        976.8      6300.0     12.0          550.0  Industrial UAV
# TATTU_TATTU_PLUS_3_0_22000MAH_51_8V_25C_14S1P_LIPO      LIPO  14S1P         51.8           22.0       1139.6      8800.0     14.0          550.0  Industrial UAV
# TATTU_TATTU_R_LINE_4500MAH_6S_95C_LIPO_BATTERY_PAC      LIPO   6S1P         22.2            4.5         99.9      1000.0      6.0          428.0  Industrial UAV
# TATTU_TATTU_PLUS_1_0_COMPACT_VERSION_16000MAH_44_4      LIPO  12S1P         44.4           16.0        710.4      4250.0     12.0          240.0  Industrial UAV
#            TATTU_TA_PLUS1_0_15C_16000_12S1P_C_XT90      LIPO  12S1P         44.4           16.0        710.4      4250.0     12.0          240.0  Industrial UAV
#               TATTU_TATTU_30C_22_2V_12000_6S1P_EC5      LIPO   6S7P         22.2           12.0        266.4      1000.0     42.0          360.0  Industrial UAV
# TATTU_TATTU_40000MAH_6S_10C_22_8V_HIGH_VOLTAGE_UAV      LIPO   6S1P         22.2           40.0        888.0      4130.0      6.0          400.0  Industrial UAV
#                        TATTU_TA_30C_10000_6S1P_EC5      LIPO   6S7P         22.2           10.0        222.0      1000.0     42.0          300.0  Industrial UAV
#                       TATTU_TA_30C_16000_6S1P_XT90      LIPO   6S7P         22.2           16.0        355.2      1000.0     42.0          480.0  Industrial UAV
#                   TATTU_TA_30C_16000_6S1P_AS_AS150      LIPO   6S7P         22.2           16.0        355.2      1000.0     42.0          480.0  Industrial UAV
# TATTU_TATTU_22_8_25C_6S_11000_MAH_HIGH_VOLTAGE_LIP      LIPO   6S7P         22.2           11.0        244.2      1000.0     42.0          275.0  Industrial UAV
# TATTU_TATTU_22_8_V_25C_6S_11000_MAH_HIGH_VOLTAGE_L      LIPO   6S7P         22.2           11.0        244.2      1000.0     42.0          275.0  Industrial UAV
# TATTU_TATTU_22_8V_15C_6S_17000MAH_LIPO_BATTERY_WIT      LIPO   6S7P         22.2           17.0        377.4      1000.0     42.0          255.0  Industrial UAV
# TATTU_TATTU_22_8V_15C_6S_17000_MAH_LIPO_BATTERY_WI      LIPO   6S7P         22.2           17.0        377.4      1000.0     42.0          255.0  Industrial UAV
# TATTU_TATTU_PRO_25C_16000MAH_12S1P_AS150_SMART_LIP      LIPO  12S1P         44.4           16.0        710.4      4650.0     12.0          400.0  Industrial UAV
# TATTU_TATTU_PLUS_25C_22000MAH_6S1P_XT90_SMART_LIPO      LIPO   6S9P         22.2           22.0        488.4      2650.0     54.0          550.0  Industrial UAV
# TATTU_TATTU_PLUS2_15C_12000MAH_6S1P_EC5_SMART_LIPO      LIPO   6S9P         22.2           12.0        266.4      1670.0     54.0          180.0  Industrial UAV
# TATTU_TATTU_PLUS_15C_12000MAH_6S1P_AS150_XT150_PLU      LIPO   6S9P         22.2           12.0        266.4      1670.0     54.0          180.0  Industrial UAV
# TATTU_TATTU_PLUS_22_2V_25C_10000MAH_6S_LIPO_SMART_      LIPO   6S9P         22.2           10.0        222.0      1517.0     54.0          250.0  Industrial UAV
# TATTU_TATTU_PLUS_22_2V_25C_6S_LIPO_BATTERY_10000_M      LIPO   6S9P         22.2           10.0        222.0      1517.0     54.0          250.0  Industrial UAV
# TATTU_TATTU_PLUS_22000_MAH_6S_1P_LIPO_SMART_BATTER      LIPO   6S9P         22.2           22.0        488.4      2650.0     54.0          550.0  Industrial UAV
# TATTU_TATTU_5200MAH_14_8V_35C_4S1P_LIPO_BATTERY_PA      LIPO   4S1P         14.8            5.2         77.0      1000.0      4.0          182.0  Industrial UAV
# TATTU_TATTU_10000MAH_14_8V_25C_4S1P_LIPO_BATTERY_P      LIPO   4S1P         14.8           10.0        148.0      1000.0      4.0          250.0  Industrial UAV
# TATTU_TATTU_4500MAH_22_2V_25C_6S1P_LIPO_BATTERY_PA      LIPO   6S1P         22.2            4.5         99.9      1000.0      6.0          112.0  Industrial UAV
# TATTU_TATTU_6000MAH_6S1P_35C_22_2V_LIPO_BATTERY_PA      LIPO   6S1P         22.2            6.0        133.2      1000.0      6.0          210.0  Industrial UAV
# TATTU_TATTU_7000MAH_6S1P_25C_22_2V_LIPO_BATTERY_PA      LIPO   6S1P         22.2            7.0        155.4       870.0      6.0          175.0  Industrial UAV
# TATTU_TATTU_8000MAH_22_2V_25C_6S1P_LIPO_BATTERY_PA      LIPO   6S1P         22.2            8.0        177.6      1000.0      6.0          200.0  Industrial UAV
# TATTU_TATTU_30000MAH_22_2V_25C_6S1P_LIPO_BATTERY_P      LIPO   6S7P         22.2           30.0        666.0      3673.0     42.0          750.0  Industrial UAV
# TATTU_TATTU_12000MAH_6S1P_15C_LIPO_BATTERY_PACK_WI      LIPO   6S1P         22.2           12.0        266.4      1620.0      6.0          180.0  Industrial UAV
# TATTU_TATTU_9000MAH_22_2V_6S1P_25C_LIPO_BATTERY_PA      LIPO   6S1P         22.2            9.0        199.8      1000.0      6.0          225.0  Industrial UAV
# GREPOW_4_45_V_ULTRA_HIGH_VOLTAGE_SERIES_BATTERY_PA      LIPO   4S1P         14.8            2.2         33.3      1072.0      4.0            7.0  Industrial UAV
#    GREPOW_COMPACT_SMART_BATTERIES_TATTU_NEO_SERIES      LIPO   6S1P         22.2           33.0        732.6      2804.0      6.0          330.0  Industrial UAV
#                 GREPOW_TATTU_6S_LIPO_DRONE_BATTERY      LIPO   6S1P         22.2            4.5         99.9       650.0      6.0           45.0  Industrial UAV
#                GREPOW_TATTU_12S_LIPO_DRONE_BATTERY      LIPO  12S1P         44.4           10.0        444.0      2800.0     12.0          100.0  Industrial UAV
#             GREPOW_TATTU_PLUS_SERIES_DRONE_BATTERY      LIPO   6S1P         22.2           10.0        222.0      1466.0      6.0          250.0  Industrial UAV
#            GREPOW_TATTU_AGRICULTURAL_DRONE_BATTERY      LIPO  18S1P         66.6           16.0       1065.6      4550.0     18.0          400.0  Industrial UAV
#                 GREPOW_TATTU_4S_LIPO_DRONE_BATTERY      LIPO   4S1P         14.8            3.7         54.8       361.0      4.0          166.0  Industrial UAV
# GREPOW_LOW_TEMPERATURE_6S_14500MAH_22_2V_30C_LIPO_      LIPO   6S1P         22.2           14.5        321.9      1961.0      6.0          435.0  Industrial UAV
#   GREPOW_TATTU_12S_10000MAH_44_4V_30C_LIPO_BATTERY      LIPO  12S1P         44.4           10.0        444.0      2800.0     12.0          300.0  Industrial UAV
# GREPOW_TATTU_G_TECH_4S_16000MAH_14_8V_30C_LIPO_DRO      LIPO   4S1P         14.8           16.0        236.8      1351.0      4.0          480.0  Industrial UAV
# GREPOW_TATTU_G_TECH_4S_22000MAH_14_8V_25C_LIPO_DRO      LIPO   4S1P         14.8           22.0        325.6      2450.0      4.0          550.0  Industrial UAV
#  GREPOW_15C_16000_12S_LIPO_TATTU_SMART_UAV_BATTERY      LIPO  12S1P         44.4           16.0        710.4      4250.0     12.0          240.0  Industrial UAV
# GREPOW_TATTU_PRO_12S_22000MAH_45_6V_25C_LIPO_SMART      LIPO  12S1P         44.4           22.0        976.8      5750.0     12.0          550.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_22000MAH_22_2V_30C_LIPO_DRO      LIPO   6S1P         22.2           22.0        488.4      2460.0      6.0          660.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_8000MAH_22_2V_25C_LIPO_DRON      LIPO   6S1P         22.2            8.0        177.6      1140.0      6.0          200.0  Industrial UAV
#  GREPOW_25C_22000_14S_LIPO_TATTU_PRO_SMART_BATTERY      LIPO  14S1P         51.8           22.0       1139.6      7200.0     14.0          550.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_25000MAH_22_8V_10C_LIPO_DRO      LIPO   6S7P         22.2           25.0        555.0      2542.0     42.0          250.0  Industrial UAV
# GREPOW_6S_22000MAH_22_2V_25C_LIPO_SMART_DRONE_BATT      LIPO   6S9P         22.2           22.0        488.4      2640.0     54.0          550.0  Industrial UAV
# GREPOW_TATTU_PLUS_1_0_12S_10000MAH_44_4V_15C_LIPO_      LIPO  12S1P         44.4           10.0        444.0      2978.0     12.0          150.0  Industrial UAV
# GREPOW_6S_16000MAH_22_2V_15C_LIPO_SMART_DRONE_BATT      LIPO   6S9P         22.2           16.0        355.2      2063.0     54.0          240.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_17000MAH_22_8V_15C_LIPO_DRO      LIPO   6S7P         22.2           17.0        377.4      1857.0     42.0          255.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_10000MAH_22_2V_30C_LIPO_DRO      LIPO   6S1P         22.2           10.0        222.0      1350.0      6.0          300.0  Industrial UAV
# GREPOW_TATTU_6S_9000MAH_22_2V_25C_LIPO_DRONE_BATTE      LIPO   6S7P         22.2            9.0        199.8      1173.0     42.0          225.0  Industrial UAV
# GREPOW_TATTU_6S_40000MAH_22_8V_10C_LIPO_DRONE_BATT      LIPO   6S1P         22.2           40.0        888.0      4130.0      6.0          400.0  Industrial UAV
# GREPOW_TATTU_6S_32000MAH_22_8V_10C_LIPO_DRONE_BATT      LIPO   6S1P         22.2           32.0        710.4      3420.0      6.0          320.0  Industrial UAV
#       GREPOW_25C_10000_6S_LIPO_TATTU_SMART_BATTERY      LIPO   6S1P         22.2           10.0        222.0      1517.0      6.0          250.0  Industrial UAV
# GREPOW_TATTU_23000MAH_22_8_V_LIHV_POUCH_CELL_UAV_B      LIPO   6S7P         22.2           23.0        510.6      2474.0     42.0          575.0  Industrial UAV
# GREPOW_6S_12000MAH_22_2V_15C_LIPO_DRONE_SMART_BATT      LIPO   6S9P         22.2           12.0        266.4      1670.0     54.0          180.0  Industrial UAV
# GREPOW_TATTU_PRO_12S_22000MAH_44_4V_25C_LIPO_SMART      LIPO  12S1P         44.4           22.0        976.8      6300.0     12.0          550.0  Industrial UAV
# GREPOW_TATTU_3_0_14S_19000MAH_51_8V_25C_LIPO_SMART      LIPO  14S1P         51.8           19.0        984.2      7900.0     14.0          475.0  Industrial UAV
# GREPOW_TATTU_3_0_14S_22000MAH_51_8V_25C_LIPO_SMART      LIPO  14S1P         51.8           22.0       1139.6      8800.0     14.0          550.0  Industrial UAV
# GREPOW_TATTU_3_0_14S_25000MAH_51_8V_25C_LIPO_SMART      LIPO  14S1P         51.8           25.0       1295.0      9600.0     14.0          625.0  Industrial UAV
# GREPOW_TATTU_PLUS_1_0_12S_22000MAH_44_4V_25C_LIPO_      LIPO  12S1P         44.4           22.0        976.8      6058.0     12.0          550.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_11000MAH_22_8V_25C_LIPO_DRO      LIPO   6S7P         22.2           11.0        244.2      1296.0     42.0          275.0  Industrial UAV
#    GREPOW_6S_16000MAH_22_2V_30C_LIPO_DRONE_BATTERY      LIPO   6S1P         22.2           16.0        355.2      1974.0      6.0          480.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_12000MAH_22_2V_30C_LIPO_DRO      LIPO   6S1P         22.2           12.0        266.4      1532.0      6.0          360.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_23000MAH_22_8V_25C_LIPO_DRO      LIPO   6S1P         22.2           23.0        510.6      2474.0      6.0          575.0  Industrial UAV
# GREPOW_TATTU_3S_10000MAH_11_1V_15C_LIPO_DRONE_BATT      LIPO   3S1P         11.1           10.0        111.0       595.0      3.0          150.0  Industrial UAV
# GREPOW_TATTU_3S_8000MAH_11_1V_15C_LIPO_DRONE_BATTE      LIPO   3S1P         11.1            8.0         88.8       529.0      3.0          120.0  Industrial UAV
# GREPOW_TATTU_G_TECH_4S_5200MAH_14_8V_35C_LIPO_DRON      LIPO   4S1P         14.8            5.2         77.0       436.0      4.0          182.0  Industrial UAV
# GREPOW_TATTU_4S_6750MAH_14_8V_25C_LIPO_DRONE_BATTE      LIPO   4S1P         14.8            6.8         99.9       620.0      4.0          169.0  Industrial UAV
# GREPOW_TATTU_4S_10000MAH_14_8V_30C_LIPO_DRONE_BATT      LIPO   4S1P         14.8           10.0        148.0       935.0      4.0          300.0  Industrial UAV
# GREPOW_TATTU_4S_10000MAH_14_8V_25C_LIPO_DRONE_BATT      LIPO   4S1P         14.8           10.0        148.0       940.0      4.0          250.0  Industrial UAV
# GREPOW_TATTU_4S_12000MAH_14_8V_30C_LIPO_DRONE_BATT      LIPO   4S1P         14.8           12.0        177.6      1057.0      4.0          360.0  Industrial UAV
# GREPOW_TATTU_4S_22000MAH_14_8V_30C_LIPO_DRONE_BATT      LIPO   4S1P         14.8           22.0        325.6      1677.0      4.0          660.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_30000MAH_22_2V_25C_LIPO_DRO      LIPO   6S1P         22.2           30.0        666.0      3494.0      6.0          750.0  Industrial UAV
# GREPOW_TATTU_6S_28000MAH_22_2V_25C_LIPO_DRONE_BATT      LIPO   6S7P         22.2           28.0        621.6      3413.0     42.0          700.0  Industrial UAV
# GREPOW_TATTU_6S_4500MAH_22_2V_25C_LIPO_DRONE_BATTE      LIPO   6S7P         22.2            4.5         99.9       650.0     42.0          112.0  Industrial UAV
# GREPOW_TATTU_6S_6000MAH_22_2V_35C_LIPO_DRONE_BATTE      LIPO   6S7P         22.2            6.0        133.2       885.0     42.0          210.0  Industrial UAV
# GREPOW_TATTU_G_TECH_6S_7000MAH_22_2V_25C_LIPO_DRON      LIPO   6S7P         22.2            7.0        155.4       870.0     42.0          175.0  Industrial UAV
# GREPOW_TATTU_G_TECH_4S_3700MAH_14_8V_45C_LIPO_DRON      LIPO   4S1P         14.8            3.7         54.8       361.0      4.0          166.0  Industrial UAV
# GREPOW_TATTU_PRO_14S_22000MAH_53_2V_25C_LIPO_SMART      LIPO  14S1P         51.8           22.0       1139.6      6550.0     14.0          550.0  Industrial UAV
# GREPOW_TATTU_3_0_14S_22000MAH_53_2V_25C_LIPO_SMART      LIPO  14S1P         51.8           22.0       1139.6      7950.0     14.0          550.0  Industrial UAV
# GREPOW_TATTU_3_0_14S_10500MAH_53_2V_25C_LIPO_SMART      LIPO  14S1P         51.8           10.5        543.9      4100.0     14.0          262.0  Industrial UAV
# GREPOW_TATTU_PRO_12S_16000MAH_45_6V_25C_LIPO_DRONE      LIPO  12S1P         44.4           16.0        710.4      4650.0     12.0          400.0  Industrial UAV

# %%
# ── SELECT BATTERIES TO ANALYSE ───────────────────────────────────────────────
# Run 00_battery_selector first to pre-select batteries via filters.
# If a selection was saved there, it is loaded automatically below.
# Override by setting SELECTED_BATTERIES to a list of IDs or 'ALL'.

# Load pre-selection from 00_battery_selector (analysis_config.json)
import json as _j, os as _o
_pre = None
if _o.path.exists(CFG_PATH):
    with open(CFG_PATH) as _f:
        _pre = _j.load(_f).get('selected_batteries')

if _pre:
    print(f'Pre-selection loaded from 00_battery_selector: {len(_pre)} pack(s)')
    SELECTED_BATTERIES = _pre
else:
    SELECTED_BATTERIES = 'ALL'   # <── override: e.g. ['BAT_MID_6S2P', 'BAT_MID_6S4P']

# ─────────────────────────────────────────────────────────────────────────────
if SELECTED_BATTERIES == 'ALL':
    selected_ids = list(db.packs.keys())
else:
    missing = [b for b in SELECTED_BATTERIES if b not in db.packs]
    if missing:
        raise ValueError(f'Unknown battery IDs: {missing}')
    selected_ids = list(SELECTED_BATTERIES)

selected_packs = {bid: db.packs[bid] for bid in selected_ids}
print(f'Batteries selected for analysis ({len(selected_ids)}):')
for bid in selected_ids:
    p = db.packs[bid]
    print(f'  {bid:<30} {p.chemistry_id:<10} {p.pack_energy_wh:.0f} Wh  {p.pack_weight_g:.0f} g')

# Energy vs weight comparison chart
MAX_LABEL = 24
chem_colors = {'LIPO':'#FFB347','LION21':'#4488FF','LIFEPO4':'#66BB6A',
               'SSS':'#AB47BC','LITO':'#26C6DA','LION':'#FF7043'}
n_sel = len(selected_ids)
fig_w = max(9, min(14, 7 + n_sel * 0.05))
fig, ax = plt.subplots(figsize=(fig_w, 6))
fig.suptitle(f'Selected Batteries — Energy vs Weight ({n_sel} packs)',
             fontweight='bold')

for idx, bid in enumerate(selected_ids):
    p = db.packs[bid]
    color = chem_colors.get(p.chemistry_id, '#888')
    ax.scatter(p.pack_weight_g, p.pack_energy_wh, s=100, color=color,
               edgecolors='black', linewidths=0.5, zorder=4)
    if n_sel <= 20:
        lbl = bid[:MAX_LABEL]
        ax.annotate(lbl, (p.pack_weight_g, p.pack_energy_wh),
                    textcoords='offset points', xytext=(5, 3), fontsize=7,
                    clip_on=True)
    else:
        ax.annotate(str(idx + 1), (p.pack_weight_g, p.pack_energy_wh),
                    textcoords='offset points', xytext=(3, 2), fontsize=6,
                    clip_on=True)

ax.set_xlabel('Pack weight (g)')
ax.set_ylabel('Pack energy (Wh)')
patches = [mpatches.Patch(color=c, label=k) for k, c in chem_colors.items()
           if any(db.packs[b].chemistry_id == k for b in selected_ids)]
ax.legend(handles=patches, fontsize=9, loc='upper left', framealpha=0.8)
if n_sel > 20:
    ax.set_title(f'Labels are row numbers (1–{n_sel}); see table above for IDs.',
                 fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# Pre-selection loaded from 00_battery_selector: 6 pack(s)
# Batteries selected for analysis (6):
#   BAT_LE_12S2P                   LION21     350 Wh  1656 g
#   GREPOW_TATTU_12S_LIPO_DRONE_BATTERY LIPO       444 Wh  2800 g
#   GREPOW_TATTU_12S_10000MAH_44_4V_30C_LIPO_BATTERY LIPO       444 Wh  2800 g
#   TATTU_TATTU_PLUS_1_0_COMPACT_VERSION_10000MAH_44_4 LIPO       444 Wh  2978 g
#   GREPOW_TATTU_PLUS_1_0_12S_10000MAH_44_4V_15C_LIPO_ LIPO       444 Wh  2978 g
#   TATTU_TATTU_SEMI_SOLID_STATE_330WH_KG_25000MAH_10C LIPO       1110 Wh  3788 g

# %% [markdown]
# ## 4b · Multi-Battery Combination (optional)
#
# Combine multiple identical packs into a single virtual pack for analysis.
#
# - **Series**: voltages add, capacity stays the same (higher voltage)
# - **Parallel**: capacities add, voltage stays the same (more energy/runtime)
#
# Leave `BATTERY_COMBINATION = None` to skip and analyse packs individually.

# %%
from batteries.builder import combine_packs

# ── MULTI-BATTERY COMBINATION ──────────────────────────────────────────────────
# Set to None to analyse packs individually (default).
# Or specify packs and topology to create a combined virtual pack.
#
# Examples:
#   BATTERY_COMBINATION = {'packs': ['BAT_MID_6S2P', 'BAT_MID_6S2P'], 'topology': 'series'}
#   BATTERY_COMBINATION = {'packs': ['BAT_MID_6S4P', 'BAT_MID_6S4P'], 'topology': 'parallel'}

BATTERY_COMBINATION = None   # <── change to dict to combine, or leave None

# ─────────────────────────────────────────────────────────────────────────────
COMBINED_PACK = None
combined_pack_id = None

if BATTERY_COMBINATION is not None:
    combo_ids = BATTERY_COMBINATION.get('packs', [])
    topology  = BATTERY_COMBINATION.get('topology', 'series').lower()
    missing   = [b for b in combo_ids if b not in db.packs]
    if missing:
        raise ValueError(f'Unknown battery IDs in combination: {missing}')
    if len(combo_ids) < 2:
        raise ValueError('BATTERY_COMBINATION requires at least 2 pack IDs')

    src_packs = [db.packs[bid] for bid in combo_ids]
    COMBINED_PACK = combine_packs(src_packs, topology=topology)
    combined_pack_id = COMBINED_PACK.battery_id

    print(f'\nCombined pack ({topology.upper()}):')
    print(f'  ID           : {COMBINED_PACK.battery_id}')
    print(f'  Voltage nom  : {COMBINED_PACK.pack_voltage_nom:.1f} V')
    print(f'  Capacity     : {COMBINED_PACK.pack_capacity_ah:.2f} Ah')
    print(f'  Energy       : {COMBINED_PACK.pack_energy_wh:.0f} Wh')
    print(f'  Max I cont   : {COMBINED_PACK.max_cont_discharge_a:.1f} A')
    print(f'  IR           : {COMBINED_PACK.internal_resistance_mohm:.2f} m\u03a9')
    print(f'  Weight       : {COMBINED_PACK.pack_weight_g:.0f} g')

    # Add to selected_ids if not already present
    if combined_pack_id not in selected_ids:
        selected_ids.append(combined_pack_id)
    # Register in db.packs so all notebooks can use it
    db.packs[combined_pack_id] = COMBINED_PACK
else:
    print('No multi-battery combination configured.')
# Out:
# No multi-battery combination configured.

# %% [markdown]
# ## 5 · Save Configuration

# %%
config = {
    'uav_id':             UAV_ID,
    'custom_equipment':   CUSTOM_EQUIPMENT,
    'mission_id':         MISSION_ID,
    'ambient_temp_c':     AMBIENT_TEMP_C,
    'temp_sweep':         TEMP_SWEEP,
    'selected_batteries': selected_ids,
    'battery_combination': BATTERY_COMBINATION,
    'combined_pack_id':    combined_pack_id,
}

with open(CFG_PATH, 'w') as f:
    json.dump(config, f, indent=2)

print(f'Configuration saved to {CFG_PATH}')
print()
print('═' * 50)
print('  UAV            :', UAV_ID)
print('  Mission        :', MISSION_ID)
print('  Temperature    :', AMBIENT_TEMP_C, '°C')
print('  Temp sweep     :', TEMP_SWEEP)
print('  Batteries      :', selected_ids)
print('═' * 50)
print()
print('You can now run Notebooks 01–05.')
print('They will load this config automatically.')
# Out:
# Configuration saved to analysis_config.json
#
# ══════════════════════════════════════════════════
#   UAV            : HEX_SURVEY_900
#   Mission        : SURVEY_STD
#   Temperature    : 25.0 °C
#   Temp sweep     : [-10, -5, 0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
#   Batteries      : ['BAT_LE_12S2P', 'GREPOW_TATTU_12S_LIPO_DRONE_BATTERY', 'GREPOW_TATTU_12S_10000MAH_44_4V_30C_LIPO_BATTERY', 'TATTU_TATTU_PLUS_1_0_COMPACT_VERSION_10000MAH_44_4', 'GREPOW_TATTU_PLUS_1_0_12S_10000MAH_44_4V_15C_LIPO_', 'TATTU_TATTU_SEMI_SOLID_STATE_330WH_KG_25000MAH_10C']
# ══════════════════════════════════════════════════
#
# You can now run Notebooks 01–05.
# They will load this config automatically.

# %% [markdown]
# ---
# ## How other notebooks use this config
#
# Add the following snippet near the top of any notebook to load your settings:
#
# ```python
# import json, os
# CFG_PATH = 'analysis_config.json'
# if os.path.exists(CFG_PATH):
#     with open(CFG_PATH) as f:
#         cfg = json.load(f)
#     UAV_ID             = cfg.get('uav_id', 'HEX_SURVEY_900')
#     MISSION_ID         = cfg.get('mission_id', 'SURVEY_STD')
#     AMBIENT_TEMP_C     = cfg.get('ambient_temp_c', 25.0)
#     TEMP_SWEEP         = cfg.get('temp_sweep', [25])
#     SELECTED_BATTERIES = cfg.get('selected_batteries', list(db.packs.keys()))
#     print('Loaded config from', CFG_PATH)
# else:
#     print('No config found — using defaults')
# ```
